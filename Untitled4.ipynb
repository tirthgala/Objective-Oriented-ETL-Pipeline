# %%
# Import necessary libraries
import sqlite3
import pandas as pd

# Connect to the SQLite database
database = '/content/database.sqlite'
connection = sqlite3.connect(database)

# %%
# Define SQL query
team_query = "SELECT * FROM Team;"

# Execute the query and load the data into a pandas DataFrame
team_df = pd.read_sql_query(team_query, connection)

# Display the first few rows of the DataFrame
team_df
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
# !apt-get install graphviz
# !pip install pydot
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# ...

# %%
import pydot
from IPython.display import Image, display

# Define the graph
graph = pydot.Dot(graph_type='graph')

# Add nodes
nodes = {
    "Team": pydot.Node("Team", shape='ellipse', style='filled', fillcolor='lightblue'),
    "Match": pydot.Node("Match", shape='ellipse', style='filled', fillcolor='lightblue'),
    "Player": pydot.Node("Player", shape='ellipse', style='filled', fillcolor='lightblue'),
    "Player_Attributes": pydot.Node("Player_Attributes", shape='ellipse', style='filled', fillcolor='lightblue'),
    "League": pydot.Node("League", shape='ellipse', style='filled', fillcolor='lightblue')
}

# Add nodes to the graph
for node in nodes.values():
    graph.add_node(node)

# Define relationships
edges = [
    ("Team", "Match"),
    ("Match", "Player"),
    ("Player", "Player_Attributes"),
    ("League", "Match")
]

# Add edges to the graph
for edge in edges:
    graph.add_edge(pydot.Edge(nodes[edge[0]], nodes[edge[1]], dir='forward'))

# Create the visualization
png_str = graph.create_png(prog='dot')

# Display the image in Jupyter Notebook
image = Image(png_str)
display(image)

# %%
# Define the tables you are interested in
tables = ['Team', 'Match', 'Player', 'Player_Attributes', 'League']

# Iterate through each table and print out its columns
for table in tables:
    query = f"PRAGMA table_info({table});"
    df = pd.read_sql_query(query, connection)
    print(f"Columns in '{table}' table:")
    print(df['name'].tolist())
    print("\n")
# Out:
# Columns in 'Team' table:
# ['id', 'team_api_id', 'team_fifa_api_id', 'team_long_name', 'team_short_name']
#
#
# Columns in 'Match' table:
# ...

# %%
# Team Performance Analysis: Assess the performance of each team across different leagues and seasons.
team_performance_query = """
SELECT t.team_long_name as 'Team Name', l.name as 'League Name', m.season as 'Season',
       COUNT(*) as 'Matches Played',
       SUM(CASE WHEN m.home_team_api_id = t.team_api_id AND m.home_team_goal > m.away_team_goal THEN 1
                WHEN m.away_team_api_id = t.team_api_id AND m.away_team_goal > m.home_team_goal THEN 1
                ELSE 0 END) as Wins,
       ROUND(SUM(CASE WHEN m.home_team_api_id = t.team_api_id AND m.home_team_goal > m.away_team_goal THEN 1
                     WHEN m.away_team_api_id = t.team_api_id AND m.away_team_goal > m.home_team_goal THEN 1
                     ELSE 0 END) * 100.0 / COUNT(*), 2) as win_percentage
FROM Match as m
JOIN Team as t ON m.home_team_api_id = t.team_api_id OR m.away_team_api_id = t.team_api_id
JOIN League as l ON m.league_id = l.id
GROUP BY t.team_long_name, l.name, m.season
ORDER BY win_percentage DESC;
"""
team_performance_df = pd.read_sql_query(team_performance_query, connection)
team_performance_df
# Out:
#              Team Name               League Name     Season  Matches Played  \
# 0             FC Porto  Portugal Liga ZON Sagres  2010/2011              30
# 1             Juventus             Italy Serie A  2013/2014              38
# 2     FC Bayern Munich     Germany 1. Bundesliga  2012/2013              34
# 3     FC Bayern Munich     Germany 1. Bundesliga  2013/2014              34
# 4                  PSV    Netherlands Eredivisie  2014/2015              34
# ...                ...                       ...        ...             ...
# 1473         Willem II    Netherlands Eredivisie  2010/2011              34
# 1474  AC Arles-Avignon            France Ligue 1  2010/2011              38
# 1475       Aston Villa    England Premier League  2015/2016              38
# 1476        Córdoba CF           Spain LIGA BBVA  2014/2015              38
# 1477      ES Troyes AC            France Ligue 1  2015/2016              38
#
#       Wins  win_percentage
# 0       27           90.00
# ...

# %%
# Top Winners in Leagues: Identify the teams with the most wins in each league for every season.
top_winners_query = """
WITH MatchResults AS (
    SELECT
        l.name AS league_name,
        m.season,
        CASE
            WHEN m.home_team_goal > m.away_team_goal THEN ht.team_long_name
            WHEN m.home_team_goal < m.away_team_goal THEN at.team_long_name
            ELSE 'Draw'
        END as match_winner
    FROM Match as m
    JOIN Team as ht ON m.home_team_api_id = ht.team_api_id
    JOIN Team as at ON m.away_team_api_id = at.team_api_id
    JOIN League as l ON m.league_id = l.id
),
RankedWinners AS (
    SELECT
        league_name,
        season,
        match_winner,
        COUNT(match_winner) OVER (PARTITION BY league_name, season, match_winner) as wins
    FROM MatchResults
    WHERE match_winner != 'Draw'
)
SELECT DISTINCT
    league_name,
    season,
    match_winner,
    wins
FROM RankedWinners
WHERE match_winner IN (
    SELECT match_winner
    FROM RankedWinners rw
    WHERE rw.league_name = RankedWinners.league_name AND rw.season = RankedWinners.season
    ORDER BY wins DESC
    LIMIT 5
)
ORDER BY league_name, season, wins DESC;
"""
top_winners_df = pd.read_sql_query(top_winners_query, connection)
top_winners_df
# Out:
#                  league_name     season    match_winner  wins
# 0     Belgium Jupiler League  2008/2009  RSC Anderlecht    24
# 1     Belgium Jupiler League  2009/2010  RSC Anderlecht    22
# 2     Belgium Jupiler League  2010/2011        KRC Genk    19
# 3     Belgium Jupiler League  2011/2012  RSC Anderlecht    20
# 4     Belgium Jupiler League  2012/2013  RSC Anderlecht    20
# ..                       ...        ...             ...   ...
# 84  Switzerland Super League  2011/2012        FC Basel    22
# 85  Switzerland Super League  2012/2013        FC Basel    21
# 86  Switzerland Super League  2013/2014        FC Basel    19
# 87  Switzerland Super League  2014/2015        FC Basel    24
# 88  Switzerland Super League  2015/2016        FC Basel    26
#
# [89 rows x 4 columns]

# %%
# Top 5 Players by Season: Determine the top 5 players each season based on their overall rating.
top_5_players_query = """
SELECT DISTINCT subquery.player_name, subquery.overall_rating, subquery.season ,subquery.Rank
FROM (
    SELECT DISTINCT p.player_name, f.overall_rating, strftime('%Y', f.date) AS season,
        ROW_NUMBER() OVER(PARTITION BY strftime('%Y', f.date) ORDER BY f.overall_rating DESC) AS Rank
    FROM player AS p
    INNER JOIN player_attributes AS f
    USING(player_api_id)
    GROUP BY player_name ,season
) AS subquery
WHERE subquery.Rank <= 5
GROUP BY subquery.season, subquery.Rank;
"""
top_5_players_df = pd.read_sql_query(top_5_players_query, connection)
top_5_players_df
# Out:
#            player_name  overall_rating season  Rank
# 0     Alessandro Nesta              91   2007     1
# 1    Cristiano Ronaldo              91   2007     2
# 2     Gianluigi Buffon              91   2007     3
# 3           Ronaldinho              91   2007     4
# 4        Thierry Henry              91   2007     5
# 5    Cristiano Ronaldo              91   2008     1
# 6        Iker Casillas              91   2008     2
# 7     Gianluigi Buffon              90   2008     3
# 8                 Kaka              90   2008     4
# 9         Lionel Messi              90   2008     5
# 10       Iker Casillas              90   2009     1
# 11        Lionel Messi              90   2009     2
# 12   Cristiano Ronaldo              89   2009     3
# 13        Carles Puyol              88   2009     4
# 14     Fernando Torres              88   2009     5
# 15        Lionel Messi              90   2010     1
# 16   Cristiano Ronaldo              89   2010     2
# ...

# %%
# League Home and Away Wins: Analyze league matches to calculate the total number of home and away wins
league_wins_query = """
SELECT
    l.name as league_name,
    SUM(CASE WHEN m.home_team_goal > m.away_team_goal THEN 1 ELSE 0 END) as home_wins,
    SUM(CASE WHEN m.away_team_goal > m.home_team_goal THEN 1 ELSE 0 END) as away_wins
FROM
    Match as m
JOIN
    League as l ON m.league_id = l.id
GROUP BY
    l.name;
"""
league_wins_df = pd.read_sql_query(league_wins_query, connection)
league_wins_df
# Out:
#                  league_name  home_wins  away_wins
# 0     Belgium Jupiler League        810        493
# 1     England Premier League       1390        867
# 2             France Ligue 1       1359        822
# 3      Germany 1. Bundesliga       1107        744
# 4              Italy Serie A       1407        814
# 5     Netherlands Eredivisie       1171        696
# 6         Poland Ekstraklasa        870        525
# 7   Portugal Liga ZON Sagres        908        611
# 8    Scotland Premier League        760        617
# 9            Spain LIGA BBVA       1485        851
# 10  Switzerland Super League        650        426

# %%
# Evaluate the distribution of player ages and their average, median and modal ratings in different age groups
import numpy as np
from scipy import stats

# Fetch data
query = """
SELECT
    CASE
        WHEN (2016 - CAST(strftime('%Y', p.birthday) AS INTEGER)) BETWEEN 18 AND 23 THEN '18-23'
        WHEN (2016 - CAST(strftime('%Y', p.birthday) AS INTEGER)) BETWEEN 24 AND 30 THEN '24-30'
        WHEN (2016 - CAST(strftime('%Y', p.birthday) AS INTEGER)) BETWEEN 31 AND 36 THEN '31-36'
        ELSE '36+'
    END as age_group,
    pa.overall_rating
FROM Player p
JOIN Player_Attributes pa ON p.player_api_id = pa.player_api_id;
"""
df = pd.read_sql_query(query, connection)

# Calculate average, median, and mode
age_analysis = df.groupby('age_group')['overall_rating'].agg(['count', 'mean', 'median'])
age_analysis['mode'] = df.groupby('age_group')['overall_rating'].agg(lambda x: stats.mode(x)[0])
age_analysis.rename(columns={'count': 'Number of Players', 'mean': 'Average Ratings', 'median': 'Median Ratings', 'mode': 'Mode Ratings'}, inplace=True)

age_analysis
# Out:
#            Number of Players  Average Ratings  Median Ratings  Mode Ratings
# age_group
# 18-23                  22432        64.441512            64.0          64.0
# 24-30                  91890        68.243683            68.0          66.0
# 31-36                  54571        70.246816            70.0          70.0
# 36+                    14249        71.137694            71.0          73.0

# %%
# !pip install --upgrade gspread

# %%
from google.colab import auth
from google.auth import default
import gspread
# Authenticate and create the interface to Sheets
# Authenticate and create the interface to Sheets
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Create a new Google Sheet (or open an existing one)
sh = gc.create('My Data Sheet')  # or gc.open('existing_sheet_name')

# Select the first sheet
worksheet = sh.get_worksheet(0)

# Function to update a worksheet with a DataFrame
def update_worksheet(worksheet, dataframe):
    worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# DataFrames to export
dataframes = {
    'League Wins': league_wins_df,
    'Top 5 Players': top_5_players_df,
    'Top Winners': top_winners_df,
    'Team Performance': team_performance_df,
    'Age Analysis': age_analysis
}

# Update each worksheet with the corresponding DataFrame
for sheet_name, dataframe in dataframes.items():
    # Create a new worksheet or open an existing one
    try:
        worksheet = sh.add_worksheet(title=sheet_name, rows="100", cols="20")
    except gspread.exceptions.APIError:
        # If worksheet exists, select it
        worksheet = sh.worksheet(sheet_name)

    # Update the worksheet with DataFrame data
    update_worksheet(worksheet, dataframe)
# Out:
# <ipython-input-31-994a1e58fd39>:18: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())
